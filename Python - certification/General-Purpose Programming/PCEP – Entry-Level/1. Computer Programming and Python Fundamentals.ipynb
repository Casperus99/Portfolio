# %% [markdown]
# # **Section 1**: Computer Programming and Python Fundamentals (18%)

# %% [markdown]
# ##  1.1 Understand fundamental terms and definitions

# %% [markdown]
# - **interpreting and the interpreter, compilation and the compiler**

# %% [markdown]
# Python is both compiled and interpreted language. <br>
# Firstly, it is compiled by the compiler which generates bytecode in the ```__pycache__``` folder. Then it is interpreted by the interpreter is a part of Pyhton Virtual Machine (PVM).
#
# ![1.1.1.png](attachment:1.1.1.png)
# ###### Source: https://www.youtube.com/watch?v=Korc0gwhUNE&t=130s

# %% [markdown]
# Normally compilation is hidden from the user. Command below enforces python to generate bytecode without interpretation.

# %% [markdown]
# ```
# PS C:\00_Kacper\Szkolenia\Python Certificate\PCEP - Entry-Level> python -m py_compile '.\Additional files\first.py'
# PS C:\00_Kacper\Szkolenia\Python Certificate\PCEP - Entry-Level> python '.\Additional files\__pycache__\first.cpython-39.pyc'
# Hello World!
# ```

# %% [markdown]
# - **lexis, syntax, and semantics**

# %%
# Variable definition
integer_number = 10
float_number = 2.3
string = "Hello!"
contaier_list = [1, 2.3, "four"]

# Function definition:
def sample_function(argument_1, argument_2):
    result = argument_1 + argument_2
    return result

# if statement
if string == "True":
    string += " indeed"

# for loop and function call
for i in range(10):
    print(i)

# while loop
while False:
    print("Infinity")

# Semantic error
x = 1
y = "Name"
print(x/y)

# Syntax error
print(x

# %% [markdown]
# ##  1.2 Understand Python’s logic and structure

# %% [markdown]
# - **keywords**

# %% [markdown]
# ![1.2.1.png](attachment:1.2.1.png)
# ###### Source: https://www.w3schools.com/python/python_ref_keywords.asp

# %% [markdown]
# - **instructions**

# %% [markdown]
# An instruction is a command to the computer, a unit of execution. Python code in this case is a set of instructions.<br>
# It can be presented as a step-by-step recipe. Python code is run by an interpreter, a program that executes instructions strictly, line by line.
#
# ###### Source: https://code-basics.com/languages/python/lessons/instructions

# %% [markdown]
# - **indentation**

# %% [markdown]
# Indentation refers to the spaces at the beginning of a code line. <br>
# Where in other programming languages the indentation in code is for readability only, the indentation in Python is very important. <br>
# Python uses indentation to indicate a block of code.
#
# ###### Soure: https://www.w3schools.com/python/gloss_python_indentation.asp

# %%
# Apropriate use of indentation
if 5 > 2:
	print("Five is greater than two!")

# Apropriate too
if 5 > 2:
  print("Five is greater than two!")

# Apropriate as well
if 5 > 2:
	   print("Five is greater than two!")
else:
 print("You are wrong!")

# Syntax Error (no indentation)
if 5 > 2:
print("Five is greater than two!")

# Another Syntax Error (indentation length in one block must be consistent)
if 5 > 2:
	print("Five is greater than two!")
		print("Five is greater than two!")
	
# Yet another Syntax Error (tab != 4x Blank)
if 5 > 2:
	print("Five is greater than two!")
    print("Five is greater than two!")

# %% [markdown]
# - **comments**

# %% [markdown]
# Basic comment in python:
# ```py
# # This is a comment
# if 5 > 2:
#     print("You're quite smart") # And this is also a comment
# ```
# Multiline comment as a multiline string:
# ```py
# """
# This is a comment
# written in
# more than just one line
# """
# if 5 > 2:
#     print("You're quite smart")
# ```

# %% [markdown]
# ## 1.3 Introduce literals and variables into code and use different numeral systems

# %% [markdown]
# - **Boolean, integers, floating-point numbers**

# %%
# Boolean variable
boolean_1 = True
boolean_2 = bool('False')

# Integer variable
integer_1 = 23
integer_2 = int(-105)
# Range: In Python 3.x as much as there is a memory

# Float variable
float_1 = 10.34
float_2 = float("infinity")
print("Float with 'infinity' argument: " + str(float_2))
# Memory: 8 bytes (1 sign bit) equivalent to double
# Max value: 1.7976931348623157e+308
# Out:
# Float with 'infinity' argument: inf

# %% [markdown]
# ###### Source: https://note.nkmk.me/en/python-sys-float-info-max-min/

# %% [markdown]
# - **scientific notation**

# %%
scientific_notation = 24e-110
print(scientific_notation)

scientific_notation = 5e+10
print(scientific_notation)
# Out:
# 2.4e-109
# 50000000000.0

# %% [markdown]
# - **strings**

# %%
a = "Hello"
print(a)

a = str(10)
print(a)

a = """Lorem ipsum dolor sit amet,
consectetur adipiscing elit,
sed do eiusmod tempor incididunt
ut labore et dolore magna aliqua."""
print(a)
# Out:
# Hello
# 10
# Lorem ipsum dolor sit amet,
# consectetur adipiscing elit,
# sed do eiusmod tempor incididunt
# ut labore et dolore magna aliqua.

# %% [markdown]
# - **binary, octal, decimal, and hexadecimal numeral systems**

# %%
decimal = 128

# Decimal to Binary
print("Decimal to Binary", decimal, "->", bin(decimal))

# Decimal to Octal
print("Decimal to Octal", decimal, "->", oct(decimal))

# Decimal to Hexadecimal
print("Decimal to Hexadecimal", decimal, "->", hex(decimal))

# Binary to Decimal
binary = "10000"
print("Binary to Decimal", binary, "->", int(binary, 2))

# Octal to Decimal
octal = "111"
print("Octal to Decimal", octal, "->", int(octal, 8))

# Hexadecimal to Decimal
hexa = "3D"
print("Hexadecimal to Decimal", hexa, "->", int(hexa, 16))

binary = 0b1010
octal = 0o127
hexa = 0xFACE
# Out:
# Decimal to Binary 128 -> 0b10000000
# Decimal to Octal 128 -> 0o200
# Decimal to Hexadecimal 128 -> 0x80
# Binary to Decimal 10000 -> 16
# Octal to Decimal 111 -> 73
# Hexadecimal to Decimal 3D -> 61

# %% [markdown]
# - **variables**

# %% [markdown]
# Python has no command for declaring a variable. A variable is created the moment you first assign a value to it. <br>
# Variables do not need to be declared with any particular type, and can even change type after they have been set.

# %%
x = 4       # x is of type int
x = "Sally" # x is now of type str
print(x)
# Out:
# Sally

# %% [markdown]
# ###### Source: https://www.w3schools.com/python/python_variables.asp

# %% [markdown]
# - **naming conventions**

# %% [markdown]
# Rules for Python variables:
#
# - A variable name must start with a letter or the underscore character
# - A variable name cannot start with a number
# - A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
# - Variable names are case-sensitive (age, Age and AGE are three different variables)

# %% [markdown]
# - **implementing PEP-8 recommendations**

# %% [markdown]
# PEP 8 - Style Guide for Python Code: https://peps.python.org/pep-0008/#global-variable-names
#
# **Function and Variable Names:**
# - Function names should be lowercase, with words separated by underscores as necessary to improve readability.
# - Variable names follow the same convention as function names.
# - mixedCase is allowed only in contexts where that’s already the prevailing style (e.g. threading.py), to retain backwards compatibility.

# %% [markdown]
# ## 1.4 Choose operators and data types adequate to the problem

# %% [markdown]
# - **numeric operators: ** * / % // + –**

# %%
x = 15
y = 10

print(x, "+", y, "=", x + y)
print(x, "-", y, "=", x - y)
print(x, "*", y, "=", x * y)
print(x, "/", y, "=", x / y)
print(x, "//", y, "=", x // y)
print(x, "**", y, "=", x ** y)
print(x, "%", y, "=", x % y)
# Out:
# 15 + 10 = 25
# 15 - 10 = 5
# 15 * 10 = 150
# 15 / 10 = 1.5
# 15 // 10 = 1
# 15 ** 10 = 576650390625
# 15 % 10 = 5

# %% [markdown]
# - **string operators: * +**

# %%
x = "Alice"
y = "Games"

print(x, "*", y, "=", x + y)
print(x, "*", 3, "=", x * 3)
# Out:
# Alice * Games = AliceGames
# Alice * 3 = AliceAliceAlice

# %% [markdown]
# - **assignment and shortcut operators**

# %%
x = 100
y = 10

# Sample shortcut assignment operators
x += y
print(x)
x //= y
print(x)
# Out:
# 110
# 11

# %% [markdown]
# - **unary and binary operators**

# %%
# Unary operators (require one operand)
-(y)
~y # Invert bites

# Binary operators (require two operands)
x + y
x = 29

# %% [markdown]
# - **priorities**

# %% [markdown]
# ![1.4.1.png](attachment:1.4.1.png)
#
# ###### Source: https://www.programiz.com/python-programming/precedence-associativity

# %% [markdown]
# - **binding**

# %% [markdown]
# Python has name binding. Name binding is the association between a name and an object (value). So in Python, we bind (or attach) a name to an object. So, when creating a variable based on the one that already exists, then this new variable (name) is binded to the same object as the old variable.
#
# ###### Source: https://mathieularose.com/python-variables

# %%
x = 10
y = 12
z = x
"""
x, z ----> 10
y   -----> 12
"""

# %% [markdown]
# - **bitwise operators: ~ & ^ | << >>**

# %%
x = 0b1101  #13
y = 0b1011  #11

a = x & y
b = x | y
c = x ^ y
d = ~x
e = x << 2
f = x >> 2

print("x =\t   " + bin(x) + "\ny =\t   " + bin(y))

a = x & y
print("x&y =\t   " + bin(a))

z = x | y 
print("x|y =\t   " + bin(b))

z = ~x  #U2 coding 1101 -> 00010
print("x^y =        " + bin(c))

z = x ^ y   #XOR
print("~x =     " + bin(d))

z = x << 2
print("x << 2 = " + bin(e))

z = x >> 2
print("x >> 2 =     " + bin(f))
# Out:
# x =	   0b1101
# y =	   0b1011
# x&y =	   0b1001
# x|y =	   0b1111
# ~x =        0b110
# x^y =     -0b1110
# x << 2 = 0b110100
# x >> 2 =     0b11

# %% [markdown]
# - **Boolean operators: *not*, *or*, *and***

# %%
x = True
y = False

print("x and y: " + str(x and y))
print("x or y: " + str(x or y))
print("not x: " + str(not x))
# Out:
# x and y: False
# x or y: True
# not x: False

# %% [markdown]
# - **Boolean expressions**

# %% [markdown]
# A Boolean expression is an expression that evaluates to produce a result which is a Boolean value. For example, the operator == tests if two values are equal.

# %% [markdown]
# - **relational operators ( == != > >= < <= )**

# %%
x = '10'
y = 10
z = 15
f = 20

print('x == y: ' + str(x == y))
print('x != y: ' + str(x != y))
print('z > y: ' + str(z > y))
print('z >= y: ' + str(z >= y))
print('z < y: ' + str(z < y))
print('z <= y: ' + str(z <= y))

print('y < z < f: ' + str(y < z < f))
# Out:
# x == y: False
# x != y: True
# z > y: True
# z >= y: True
# z < y: False
# z <= y: False
# y < z < f: True

# %% [markdown]
# - **the accuracy of floating-point numbers**

# %%
# From the below output, we can conclude that Python represents floating point numbers with precision of up to 15 significant digits.
print(1 + 1.000000000000001e-15 == 1)
print(1 + 1.000000000000001e-16 == 1)
# Out:
# False
# True

# %% [markdown]
# - **type casting**

# %% [markdown]
# There are two types of type conversion in Python:
#
# - Implicit Conversion - automatic type conversion
# - Explicit Conversion - manual type conversion

# %%
# Implicit Conversion
integer_number = 123
float_number = 1.23

new_number = integer_number + float_number

# display new value and resulting data type
print("Value:",new_number)
print("Data Type:",type(new_number))
# Out:
# Value: 124.23
# Data Type: <class 'float'>

# %%
# Explicit Conversion
num_string = '12'
num_integer = 23

print("Data type of num_string before Type Casting:",type(num_string))

# explicit type conversion
num_string = int(num_string)

print("Data type of num_string after Type Casting:",type(num_string))

num_sum = num_integer + num_string

print("Sum:",num_sum)
print("Data type of num_sum:",type(num_sum))
# Out:
# Data type of num_string before Type Casting: <class 'str'>
# Data type of num_string after Type Casting: <class 'int'>
# Sum: 35
# Data type of num_sum: <class 'int'>

# %% [markdown]
# ##  1.5 Perform Input/Output console operations

# %% [markdown]
# - **the *print()* and *input()* functions**

# %%
print("This is string")
print("And this is number " + str(10))
print("You", "can", "also", "put", "values", "like", "that", 10e3)
# Out:
# This is string
# And this is number 10
# You can also put values like that 10000.0

# %%
x = input("You can add prompt here: ")
x
# Out:
# 'This is user input'

# %% [markdown]
# - **the *sep=* and *end=* keyword parameters**

# %%
print("You can add special ending", end=" and it has to be a string")
print("Where did my", "breakline go?", sep="_my_sep_")
# Out:
# You can add special ending and it has to be a stringWhere did my_my_sep_breakline go?

# %% [markdown]
# - **the *int()* and *float()* functions**

# %%
# int(value, base)

print(int())
print(int(2.99))
# print(int('2.2')) # ValueError: invalid literal for int() with base 10: '2.2'
print(int(('22'))) # From tuple with one value
# print(int([2])) # TypeError: int() argument must be a string, a bytes-like object or a number, not 'list'
print(int('0011', 2)) # With base specified value has to be a string

print("------------")

# float(value)
print(float())
print(float((10)))
print(float(11.22))
print(float("-13.33"))
print(float("     -24.45\n"))
# print(float("abc")) # ValueError: could not convert string to float: 'abc
# Out:
# 0
# 2
# 22
# 3
# ------------
# 0.0
# 10.0
# 11.22
# -13.33
# -24.45

# %% [markdown]
# - **Additional**

# %%
# A tuple with only one object is not a tuple
x = (10)
type(x)
# Out:
# int
